# %%
from sklearn.cluster import DBSCAN
from geopy.distance import great_circle
from shapely.geometry import MultiPoint
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Point
import folium
from folium.plugins import FastMarkerCluster


def import_data():
    canadian_cities = pd.read_csv(r"C:\Users\jua12849\Documents\GitHub\GeospatialDataAnalysis\canadacities.csv")
    datum = "EPSG:4326"

    #create geodataframe containing data with all canadian cities and a point geometry column
    geometry = [Point(xy) for xy in zip(canadian_cities["lng"],canadian_cities["lat"])]
    gdf = gpd.GeoDataFrame(canadian_cities,crs=datum,geometry=geometry)

    return gdf


def create_gdf_dictionary(gdf):
    #create dictionary with complete data for each province
    d = {}
    for city in gdf.province_id.unique():
        d["city_{}".format(city)] = gdf.loc[gdf["province_id"]==city]

    return d

def obtain_provinces(d):
    provinces = list(d.keys())
    
    return provinces


def create_numpy_dictionary(d,gdf,provinces):
    #obtain province names as well as list of dictionary keys.

    #obtain lat/long data for each province and the entire country as a numpy array.
    d_lat_lon_numpy = {}
    for province in provinces:
        d_lat_lon_numpy["{}".format(province)] = [d.get(province)[["lat","lng"]].to_numpy()]

    d_lat_lon_numpy["Canada"] = [gdf[["lat","lng"]].to_numpy()]

    return d_lat_lon_numpy

def get_centermost_point(cluster):
    centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
    centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
    return tuple(centermost_point)

def perform_dbscan(d_lat_lon_numpy,epsilon=0.019,min_samples=1):
    #kms_per_radian = 6371.0088
    #epsilon = 50 / kms_per_radian
    #epsilon = 0.019
    #min_samples=1

    #perform DBSCAN algorithm to each province separately as well as the entire country
    for province in list(d_lat_lon_numpy.keys()):
        #Create DBSCAN object and apply to each latitude/longitude pair
        d_lat_lon_numpy["{}".format(province)].append(
            {"dbs_{}".format(province):DBSCAN(eps=epsilon, min_samples=min_samples,algorithm = 'ball_tree',metric='haversine').fit(np.radians(d_lat_lon_numpy.get(province)[0]))})
        #Retrieve labels obtained from algorithm
        d_lat_lon_numpy["{}".format(province)].append(
            {"{}_cluster_label".format(province):d_lat_lon_numpy.get(province)[1]["dbs_{}".format(province)].labels_})
        #Obtain cluster labels
        d_lat_lon_numpy["{}".format(province)].append(
            {"{}_num_clusters".format(province):len(set(d_lat_lon_numpy.get(province)[2]["{}_cluster_label".format(province)]))})
        #
        d_lat_lon_numpy["{}".format(province)].append(
            {"{}_clusters".format(province):
            pd.Series(d_lat_lon_numpy.get(province)[0][d_lat_lon_numpy.get(province)[2]["{}_cluster_label".format(province)] == n] for n in range(d_lat_lon_numpy["{}".format(province)][3]["{}_num_clusters".format(province)]))})

        d_lat_lon_numpy["{}".format(province)].append(
            {"{}_centermost_points".format(province):d_lat_lon_numpy.get(province)[4]["{}_clusters".format(province)].map(get_centermost_point)})

        #unzip the list of centermost points (lat,lon) tuples into separate lat/lon lists
        lats, lons = zip(*d_lat_lon_numpy.get(province)[5]["{}_centermost_points".format(province)])
        #create a pandas dataframe
        rep_points = pd.DataFrame({'lon':lons, 'lat':lats})

        d_lat_lon_numpy["{}".format(province)].append({"{}_centermost_points_numpy".format(province) : rep_points.to_numpy()})

        d_lat_lon_numpy["{}".format(province)].append(
            {"{}_gdf_cluster_samples".format(province):gpd.GeoDataFrame(rep_points, geometry=gpd.points_from_xy(rep_points.lon, rep_points.lat),crs = "EPSG:4326" )})

    return d_lat_lon_numpy

def calculate_mean_ontario_loc(d):    
    #mean location for ontario cities
    mean_lat_on = np.mean(d["city_ON"]["lat"])
    mean_lng_on = np.mean(d["city_ON"]["lng"])
    
    return mean_lat_on,mean_lng_on

def calculate_mean_canada_loc(gdf):
    #mean location for canada cities
    gdf_mean_lat = np.mean(gdf.lat)
    gdf_mean_lng = np.mean(gdf.lng)

    return gdf_mean_lat,gdf_mean_lng

def cities_dict(d_lat_lon_numpy,provinces):
    cities = {}
    for province in provinces:
        cities["{}".format(province)] = d_lat_lon_numpy.get("{}".format(province))[0]
    
    return cities

def clusters_dict(d_lat_lon_numpy,provinces):
    clusters={}
    for province in provinces:
        clusters["{}".format(province)] = d_lat_lon_numpy.get("{}".format(province))[6].get("{}_centermost_points_numpy".format(province))
    
    return clusters

def study_area_numpy(cities):
    study_area = np.concatenate([cities["city_ON"],
                                cities["city_QC"],
                                cities["city_NB"],
                                cities["city_NS"]])

    return study_area

def cluster_area_numpy(clusters):
    study_clusters = np.concatenate([clusters["city_ON"],
                                clusters["city_QC"],
                                clusters["city_NB"],
                                clusters["city_NS"]])
    
    return study_clusters


def create_map(gdf_mean_lat,gdf_mean_lng,study_area,study_clusters,zoom):

    my_map = folium.Map(location=[gdf_mean_lat,gdf_mean_lng], zoom_start=zoom)

    for point in study_clusters :
        loc = [point[1],point[0]]
        folium.Marker(location=loc,icon=folium.Icon(color="red")).add_to(my_map)
        #folium.Circle(radius=40000,location=[point[1],point[0]],color="red").add_to(my_map)

    for point in study_area :
        loc = [point[0],point[1]]
        #folium.Marker(location=loc,icon=folium.Icon(color="blue")).add_to(my_map)
        folium.Circle(radius=4000,location=loc,color="BLUE").add_to(my_map)
    
    #folium.GeoJson(data = gdf).add_to(my_map)    

    return my_map

# %%
def run_map(epsilon,min_samples):
    gdf = import_data()
    d = create_gdf_dictionary(gdf)
    provinces = obtain_provinces(d)
    d_lat_lon_numpy = create_numpy_dictionary(d,gdf,provinces)
    d_lat_lon_numpy = perform_dbscan(d_lat_lon_numpy,epsilon = epsilon,min_samples=min_samples)
    mean_lat_on,mean_lng_on = calculate_mean_ontario_loc(d)
    gdf_mean_lat, gdf_mean_lng = calculate_mean_canada_loc(gdf)
    clusters = clusters_dict(d_lat_lon_numpy,provinces)
    cities = cities_dict(d_lat_lon_numpy,provinces)
    study_area = study_area_numpy(cities)
    study_clusters = cluster_area_numpy(clusters)
    map = create_map(gdf_mean_lat,gdf_mean_lng,study_area,study_clusters,zoom=5)

    return map

# %%
run_map(epsilon = 0.09, min_samples = 2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_9128\540326939.py in <module>
# ----> 1 run_map(epsilon = 0.09, min_samples = 2)
#
# ~\AppData\Local\Temp\1\ipykernel_9128\1655733925.py in run_map(epsilon, min_samples)
#       4     provinces = obtain_provinces(d)
#       5     d_lat_lon_numpy = create_numpy_dictionary(d,gdf,provinces)
# ----> 6     d_lat_lon_numpy = perform_dbscan(d_lat_lon_numpy,epsilon = epsilon,min_samples=min_samples)
#       7     mean_lat_on,mean_lng_on = calculate_mean_ontario_loc(d)
#       8     gdf_mean_lat, gdf_mean_lng = calculate_mean_canada_loc(gdf)
#
# ~\AppData\Local\Temp\1\ipykernel_9128\1869994694.py in perform_dbscan(d_lat_lon_numpy, epsilon, min_samples)
#      75
#      76         d_lat_lon_numpy["{}".format(province)].append(
# ---> 77             {"{}_centermost_points".format(province):d_lat_lon_numpy.get(province)[4]["{}_clusters".format(province)].map(get_centermost_point)})
#      78
#      79         #unzip the list of centermost points (lat,lon) tuples into separate lat/lon lists
#
# c:\Users\jua12849\Anaconda3\envs\insights-latest\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# c:\Users\jua12849\Anaconda3\envs\insights-latest\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     868
#     869         # mapper is a function
# --> 870         new_values = map_f(values, mapper)
#     871
#     872         return new_values
#
# c:\Users\jua12849\Anaconda3\envs\insights-latest\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\1\ipykernel_9128\1869994694.py in get_centermost_point(cluster)
#      48
#      49 def get_centermost_point(cluster):
# ---> 50     centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
#      51     centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
#      52     return tuple(centermost_point)
#
# c:\Users\jua12849\Anaconda3\envs\insights-latest\lib\site-packages\shapely\geometry\point.py in x(self)
#      64     def x(self):
#      65         """Return x coordinate."""
# ---> 66         return self.coords[0][0]
#      67
#      68     @property
#
# c:\Users\jua12849\Anaconda3\envs\insights-latest\lib\site-packages\shapely\coords.py in __getitem__(self, key)
#      83         if isinstance(key, int):
#      84             if self._cseq is None or key + m < 0 or key >= m:
# ---> 85                 raise IndexError("index out of range")
#      86             if key < 0:
#      87                 i = m + key
#
# IndexError: index out of range

# %%
maps = {}

epsilons = [0.0001,0.009,0.015,0.05,0.1,0.15]

for eps in epsilons:
    maps["map_{}".format(str(eps).split(".")[1])] = run_map(epsilon=eps,min_samples=1) 
maps
# Out:
# {'map_0001': <folium.folium.Map at 0x1a7029d6a48>,
#  'map_009': <folium.folium.Map at 0x1a70289eb08>,
#  'map_015': <folium.folium.Map at 0x1a702704c88>,
#  'map_05': <folium.folium.Map at 0x1a7028e4248>,
#  'map_1': <folium.folium.Map at 0x1a702a16f48>,
#  'map_15': <folium.folium.Map at 0x1a7029f7bc8>}

# %%
maps.get("map_015")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef81bd0ca8ac57d3f5103a722fcf55eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef81bd0ca8ac57d3f5103a722fcf55eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ef81bd0ca8ac57d3f5103a722fcf55eb = L.map(
#                 &quot;map_ef81bd0ca8ac57d3f5103a722fcf55eb&quot;,
#                 {
#                     center: [47.84627721518988, -83.94354355581127],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8932e5470a926ed870e01e012ea3bc2c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef81bd0ca8ac57d3f5103a722fcf55eb);
#
#
#             var marker_2499a670c8197bb9258789114bd3bf50 = L.marker(
#                 [44.3, -79.4333],
#                 {}
#             ).addTo(map_ef81bd0ca8ac57d3f5103a722fcf55eb);
#
#
#             var icon_38656e47acf8f1f4efdd508e8a9450b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2499a670c8197bb9258789114bd3bf50.setIcon(icon_38656e47acf8f1f4efdd508e8a9450b5);
#
#
#             var marker_c2c1fb4879ba4ebf80f6133a387b703b = L.marker(
#                 [49.0153, -88.2683],
#                 {}
#             ).addTo(map_ef81bd0ca8ac57d3f5103a722fcf55eb);
#
#
#             var icon_3e45645c3867b160494635252f0feaaf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2c1fb4879ba4ebf80f6133a387b703b.setIcon(icon_3e45645c3867b160494635252f0feaaf);
#
#
#             var marker_0912d2f076539ed06d69c7a74191a569 = L.marker(
#                 [48.4667, -81.3333],
#                 {}
#             ).addTo(map_ef81bd0ca8ac57d3f5103a722fcf55eb);
#
#
#             var icon_e4bba390655f1fd0fd001bd1ae25aa9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0912d2f076539ed06d69c7a74191a569.setIcon(icon_e4bba390655f1fd0fd001bd1ae25aa9b);
#
#
#             var marker_457e3a6d727635eb30fb9dc510ff1f08 = L.marker(
#                 [49.4, -94.08],
#                 {}
#             ).addTo(map_ef81bd0ca8ac57d3f5103a722fcf55eb);
#
#
#             var icon_54d980a2d8de3e639d34c022c8405dce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_457e3a6d727635eb30fb9dc510ff1f08.setIcon(icon_54d980a2d8de3e639d34c022c8405dce);
#
#
#             var marker_6c887d3191850254cf12b7c31bde0e1f = L.marker(
#                 [49.4167, -91.6667],
#                 {}
#             ).addTo(map_ef81bd0ca8ac57d3f5103a722fcf55eb);
#
#
#             var icon_60e34383510132eb5ad41a4d777691bf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6c887d3191850254cf12b7c31bde0e1f.setIcon(icon_60e34383510132eb5ad41a4d777691bf);
#
#
#             var marker_afd88bd01ede0c7228b4e150a86eb4b3 = L.marker(
#                 [50.0, -86.7333],
#                 {}
#             ).addTo(map_ef81bd0ca8ac57d3f5103a722fcf55eb);
#
#
#             var icon_592b32ad94360ad1c4f484f461cf2e07 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_afd88bd01ede0c7228b4e150a86eb4b3.setIcon(icon_592b32ad94360ad1c4f484f461cf2e07);
#
#
#             var marker_f5c5f5165c5e52cead113f4825255c4e = L.marker(
#                 [51.0333, -93.8333],
#                 {}
#             ).addTo(map_ef81bd0ca8ac57d3f5103a722fcf55eb);
#
#
#             var icon_e26873f8bd2012431d1ae9ba5eecb6ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;inf

# %%
from sklearn.cluster import DBSCAN
from geopy.distance import great_circle
from shapely.geometry import MultiPoint
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Point
import folium
from folium.plugins import FastMarkerCluster

class create_cluster_map:
    def __init__(self,epsilon,min_samples):
        self.epsilon = epsilon
        self.min_samples = min_samples

    
    def import_data(self):
        data_path = r"C:\Users\jua12849\Documents\GitHub\GeospatialDataAnalysis\canadacities.csv"
        canadian_cities = pd.read_csv(data_path)
        datum = "EPSG:4326"

        #create geodataframe containing data with all canadian cities and a point geometry column
        geometry = [Point(xy) for xy in zip(canadian_cities["lng"],canadian_cities["lat"])]
        gdf = gpd.GeoDataFrame(canadian_cities,crs=datum,geometry=geometry)

        return gdf


    def create_gdf_dictionary(self,gdf):
        #create dictionary with complete data for each province
        d = {}
        for city in gdf.province_id.unique():
            d["city_{}".format(city)] = gdf.loc[gdf["province_id"]==city]

        return d

    def obtain_provinces(self,d):
        provinces = list(d.keys())
        
        return provinces


    def create_numpy_dictionary(self,d,gdf,provinces):
        #obtain province names as well as list of dictionary keys.

        #obtain lat/long data for each province and the entire country as a numpy array.
        d_lat_lon_numpy = {}
        for province in provinces:
            d_lat_lon_numpy["{}".format(province)] = [d.get(province)[["lat","lng"]].to_numpy()]

        d_lat_lon_numpy["Canada"] = [gdf[["lat","lng"]].to_numpy()]

        return d_lat_lon_numpy

    
    def get_centermost_point(self,cluster):
        centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
        centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
        return tuple(centermost_point)

    def perform_dbscan(self,d_lat_lon_numpy,epsilon=0.019,min_samples=1):
        #kms_per_radian = 6371.0088
        #epsilon = 50 / kms_per_radian
        #epsilon = 0.019
        #min_samples=1

        #perform DBSCAN algorithm to each province separately as well as the entire country
        for province in list(d_lat_lon_numpy.keys()):
            #Create DBSCAN object and apply to each latitude/longitude pair
            d_lat_lon_numpy["{}".format(province)].append(
                {"dbs_{}".format(province):DBSCAN(eps=epsilon, min_samples=min_samples,algorithm = 'ball_tree',metric='haversine').fit(np.radians(d_lat_lon_numpy.get(province)[0]))})
            #Retrieve labels obtained from algorithm
            d_lat_lon_numpy["{}".format(province)].append(
                {"{}_cluster_label".format(province):d_lat_lon_numpy.get(province)[1]["dbs_{}".format(province)].labels_})
            #Obtain cluster labels
            d_lat_lon_numpy["{}".format(province)].append(
                {"{}_num_clusters".format(province):len(set(d_lat_lon_numpy.get(province)[2]["{}_cluster_label".format(province)]))})
            #
            d_lat_lon_numpy["{}".format(province)].append(
                {"{}_clusters".format(province):
                pd.Series(d_lat_lon_numpy.get(province)[0][d_lat_lon_numpy.get(province)[2]["{}_cluster_label".format(province)] == n] for n in range(d_lat_lon_numpy["{}".format(province)][3]["{}_num_clusters".format(province)]))})

            d_lat_lon_numpy["{}".format(province)].append(
                {"{}_centermost_points".format(province):d_lat_lon_numpy.get(province)[4]["{}_clusters".format(province)].map(self.get_centermost_point)})

            #unzip the list of centermost points (lat,lon) tuples into separate lat/lon lists
            lats, lons = zip(*d_lat_lon_numpy.get(province)[5]["{}_centermost_points".format(province)])
            #create a pandas dataframe
            rep_points = pd.DataFrame({'lon':lons, 'lat':lats})

            d_lat_lon_numpy["{}".format(province)].append({"{}_centermost_points_numpy".format(province) : rep_points.to_numpy()})

            d_lat_lon_numpy["{}".format(province)].append(
                {"{}_gdf_cluster_samples".format(province):gpd.GeoDataFrame(rep_points, geometry=gpd.points_from_xy(rep_points.lon, rep_points.lat),crs = "EPSG:4326" )})

        return d_lat_lon_numpy

    def calculate_mean_ontario_loc(self,d):    
        #mean location for ontario cities
        mean_lat_on = np.mean(d["city_ON"]["lat"])
        mean_lng_on = np.mean(d["city_ON"]["lng"])
        
        return mean_lat_on,mean_lng_on

    def calculate_mean_canada_loc(self,gdf):
        #mean location for canada cities
        gdf_mean_lat = np.mean(gdf.lat)
        gdf_mean_lng = np.mean(gdf.lng)

        return gdf_mean_lat,gdf_mean_lng

    def cities_dict(self,d_lat_lon_numpy,provinces):
        cities = {}
        for province in provinces:
            cities["{}".format(province)] = d_lat_lon_numpy.get("{}".format(province))[0]
        
        return cities

    def clusters_dict(self,d_lat_lon_numpy,provinces):
        clusters={}
        for province in provinces:
            clusters["{}".format(province)] = d_lat_lon_numpy.get("{}".format(province))[6].get("{}_centermost_points_numpy".format(province))
        
        return clusters

    def study_area_numpy(self,cities):
        study_area = np.concatenate([cities["city_ON"],
                                    cities["city_QC"],
                                    cities["city_NB"],
                                    cities["city_NS"]])

        return study_area

    def cluster_area_numpy(self,clusters):
        study_clusters = np.concatenate([clusters["city_ON"],
                                    clusters["city_QC"],
                                    clusters["city_NB"],
                                    clusters["city_NS"]])
        
        return study_clusters


    def create_map(self,gdf_mean_lat,gdf_mean_lng,study_area,study_clusters,zoom):

        my_map = folium.Map(location=[gdf_mean_lat,gdf_mean_lng], zoom_start=zoom)

        for point in study_clusters :
            loc = [point[1],point[0]]
            folium.Marker(location=loc,icon=folium.Icon(color="red")).add_to(my_map)
            #folium.Circle(radius=40000,location=[point[1],point[0]],color="red").add_to(my_map)

        for point in study_area :
            loc = [point[0],point[1]]
            #folium.Marker(location=loc,icon=folium.Icon(color="blue")).add_to(my_map)
            folium.Circle(radius=4000,location=loc,color="BLUE").add_to(my_map)
        
        #folium.GeoJson(data = gdf).add_to(my_map)    

        return my_map 

    
    def run_map(self):
        gdf = self.import_data()
        d = self.create_gdf_dictionary(gdf)
        provinces = self.obtain_provinces(d)
        d_lat_lon_numpy = self.create_numpy_dictionary(d,gdf,provinces)
        d_lat_lon_numpy = self.perform_dbscan(d_lat_lon_numpy,epsilon = self.epsilon,min_samples=self.min_samples)
        mean_lat_on,mean_lng_on = self.calculate_mean_ontario_loc(d)
        gdf_mean_lat, gdf_mean_lng = self.calculate_mean_canada_loc(gdf)
        clusters = self.clusters_dict(d_lat_lon_numpy,provinces)
        cities = self.cities_dict(d_lat_lon_numpy,provinces)
        study_area = self.study_area_numpy(cities)
        study_clusters = self.cluster_area_numpy(clusters)
        map = self.create_map(gdf_mean_lat,gdf_mean_lng,study_area,study_clusters,zoom=5)

        return map

    
if __name__ == "__main__":

    map_objects = []
    maps = {}
    epsilons = np.linspace(0.01,0.1,num=10, endpoint=True) 
    for epsilon in epsilons:
        
        maps["cluster_map_obj_eps_{}".format(str(epsilon).split(".")[0]+"_"+str(epsilon).split(".")[1][0:2])] = [create_cluster_map(epsilon,1)]
        maps["cluster_map_obj_eps_{}".format(str(epsilon).split(".")[0]+"_"+str(epsilon).split(".")[1][0:2])].append(
           
            maps["cluster_map_obj_eps_{}".format(str(epsilon).split(".")[0]+"_"+str(epsilon).split(".")[1][0:2])][0].run_map())

# %%
maps.keys()
# Out:
# dict_keys(['cluster_map_obj_eps_0_01', 'cluster_map_obj_eps_0_02', 'cluster_map_obj_eps_0_03', 'cluster_map_obj_eps_0_04', 'cluster_map_obj_eps_0_05', 'cluster_map_obj_eps_0_06', 'cluster_map_obj_eps_0_07', 'cluster_map_obj_eps_0_08', 'cluster_map_obj_eps_0_09', 'cluster_map_obj_eps_0_1'])

# %%
maps.get("cluster_map_obj_eps_0_01")[1]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e39ebce3e8fd6a2e421d44fa0271b0d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e39ebce3e8fd6a2e421d44fa0271b0d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e39ebce3e8fd6a2e421d44fa0271b0d5 = L.map(
#                 &quot;map_e39ebce3e8fd6a2e421d44fa0271b0d5&quot;,
#                 {
#                     center: [47.84627721518988, -83.94354355581127],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00344798a7853e4f6dbb34fee8fa9044 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e39ebce3e8fd6a2e421d44fa0271b0d5);
#
#
#             var marker_1c6fd48b892db1f7531e5daf6b9d9dda = L.marker(
#                 [44.3167, -79.0833],
#                 {}
#             ).addTo(map_e39ebce3e8fd6a2e421d44fa0271b0d5);
#
#
#             var icon_03d8a8548ac73b939220fd7fed5bcfbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1c6fd48b892db1f7531e5daf6b9d9dda.setIcon(icon_03d8a8548ac73b939220fd7fed5bcfbf);
#
#
#             var marker_7f8b76790d50ceafe390db8cbce9a73b = L.marker(
#                 [48.3822, -89.2461],
#                 {}
#             ).addTo(map_e39ebce3e8fd6a2e421d44fa0271b0d5);
#
#
#             var icon_6b423e8b4acf571d0381f7254da4fa4e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f8b76790d50ceafe390db8cbce9a73b.setIcon(icon_6b423e8b4acf571d0381f7254da4fa4e);
#
#
#             var marker_26b5fa3bae0a6d26eb98b98ef74c837f = L.marker(
#                 [46.1833, -82.95],
#                 {}
#             ).addTo(map_e39ebce3e8fd6a2e421d44fa0271b0d5);
#
#
#             var icon_7c75c5c6abb0c054020107ec3eb97528 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_26b5fa3bae0a6d26eb98b98ef74c837f.setIcon(icon_7c75c5c6abb0c054020107ec3eb97528);
#
#
#             var marker_bd69b57d5f6136eb006eca41f81df9c7 = L.marker(
#                 [48.5333, -80.4667],
#                 {}
#             ).addTo(map_e39ebce3e8fd6a2e421d44fa0271b0d5);
#
#
#             var icon_14c0f64a6054e13890873bc2f4481ac9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd69b57d5f6136eb006eca41f81df9c7.setIcon(icon_14c0f64a6054e13890873bc2f4481ac9);
#
#
#             var marker_b1b54dfd4121b7e59702a1a1ee9e8e1c = L.marker(
#                 [49.7667, -94.4833],
#                 {}
#             ).addTo(map_e39ebce3e8fd6a2e421d44fa0271b0d5);
#
#
#             var icon_f7db8c5b178b631fce435e5f218e58d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b1b54dfd4121b7e59702a1a1ee9e8e1c.setIcon(icon_f7db8c5b178b631fce435e5f218e58d1);
#
#
#             var marker_3115ded4880080fb8ef5b889b7fe81ee = L.marker(
#                 [49.7833, -92.8333],
#                 {}
#             ).addTo(map_e39ebce3e8fd6a2e421d44fa0271b0d5);
#
#
#             var icon_9fd0e362a7b184a9b4a94a3e521fb7b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3115ded4880080fb8ef5b889b7fe81ee.setIcon(icon_9fd0e362a7b184a9b4a94a3e521fb7b9);
#
#
#             var marker_0bf799de2f9843e7909fdeeafd842434 = L.marker(
#                 [48.6333, -93.8333],
#                 {}
#             ).addTo(map_e39ebce3e8fd6a2e421d44fa0271b0d5);
#
#
#             var icon_d57203144b40bebcf446e6f275b667d7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:
